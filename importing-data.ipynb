# %%
import numpy as np
import pandas as pd
import stats19

# %%
accidents_2020 = stats19.get(kind="accident", year="2020")
accidents_2020.head()
# Out:
#                 accident_year accident_reference  location_easting_osgr  \
# accident_index
# 2020010219808            2020          010219808               521389.0
# 2020010220496            2020          010220496               529337.0
# 2020010228005            2020          010228005               526432.0
# 2020010228006            2020          010228006               538676.0
# 2020010228011            2020          010228011               529324.0
#
#                 location_northing_osgr  longitude   latitude  police_force  \
# accident_index
# 2020010219808                 175144.0  -0.254001  51.462262             1
# 2020010220496                 176237.0  -0.139253  51.470327             1
# 2020010228005                 182761.0  -0.178719  51.529614             1
# 2020010228006                 184371.0  -0.001683  51.541210             1
# 2020010228011                 181286.0  -0.137592  51.515704             1
#
# ...

# %%
accident_lookup = stats19.lookup(kind="Accident")
accident_lookup.head()
# Out:
#                        code/format label
# field name
# accident_index                 NaN   NaN
# accident_year                  NaN   NaN
# accident_reference             NaN   NaN
# location_easting_osgr          NaN   NaN
# location_northing_osgr         NaN   NaN

# %%
encode_map = stats19.lookup_pairs(kind="Accident")
display(encode_map)
# Out:
#                                                                                   descriptions
# field_name
# accident_severity                                      {1: 'Fatal', 2: 'Serious', 3: 'Slight'}
# carriageway_hazards                          {0: 'None', 1: 'Vehicle load on road', 2: 'Oth...
# day_of_week                                  {1: 'Sunday', 2: 'Monday', 3: 'Tuesday', 4: 'W...
# did_police_officer_attend_scene_of_accident  {1: 'Yes', 2: 'No', 3: 'No - accident was repo...
# first_road_class                             {1: 'Motorway', 2: 'A(M)', 3: 'A', 4: 'B', 5: ...
# first_road_number                            {'1 to 9999': 'Number range', '-1': 'Unknown',...
# junction_control                             {0: 'Not at junction or within 20 metres', 1: ...
# junction_detail                              {0: 'Not at junction or within 20 metres', 1: ...
# light_conditions                             {1: 'Daylight', 4: 'Darkness - lights lit', 5:...
# ...

# %%
for field in encode_map.index:
    accidents_2020[[field]].replace(encode_map.loc[field, "descriptions"])

# %%
# Out:
#                 accident_year accident_reference  location_easting_osgr  \
# accident_index
# 2020010219808            2020          010219808               521389.0
# 2020010220496            2020          010220496               529337.0
# 2020010228005            2020          010228005               526432.0
# 2020010228006            2020          010228006               538676.0
# 2020010228011            2020          010228011               529324.0
# ...                       ...                ...                    ...
# 2020991027064            2020          991027064               343034.0
# 2020991029573            2020          991029573               257963.0
# 2020991030297            2020          991030297               383664.0
# 2020991030900            2020          991030900               277161.0
# 2020991032575            2020          991032575               240402.0
#
#                 location_northing_osgr  longitude   latitude  police_force  \
# ...

# %%
encode_map.loc["accident_severity", "descriptions"]
# Out:
# {1: 'Fatal', 2: 'Serious', 3: 'Slight'}
