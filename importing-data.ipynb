# %%
import numpy as np
import pandas as pd
import stats19

# %%
accidents_2020 = stats19.get(kind="accident", year="2020")
accidents_2020.head()
# Out:
#                 accident_year accident_reference  location_easting_osgr  \
# accident_index
# 2020010219808            2020          010219808               521389.0
# 2020010220496            2020          010220496               529337.0
# 2020010228005            2020          010228005               526432.0
# 2020010228006            2020          010228006               538676.0
# 2020010228011            2020          010228011               529324.0
#
#                 location_northing_osgr  longitude   latitude  police_force  \
# accident_index
# 2020010219808                 175144.0  -0.254001  51.462262             1
# 2020010220496                 176237.0  -0.139253  51.470327             1
# 2020010228005                 182761.0  -0.178719  51.529614             1
# 2020010228006                 184371.0  -0.001683  51.541210             1
# 2020010228011                 181286.0  -0.137592  51.515704             1
#
# ...

# %%
lookup = stats19.lookup(kind="accident")
lookup.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 lookup = stats19.lookup(kind="accident")
#       2 lookup.head()
#
# File ~\road safety\stats19.py:19, in lookup(kind)
#      14 """
#      15 import road safety data guide
#      16 """
#      17 url = "https://data.dft.gov.uk/road-accidents-safety-data/Road-Safety-Open-Dataset-Data-Guide.xlsx"
#      18 df = (
# ---> 19     pd.read_excel(url, index_col=0, usecols=[0, 1, 2, 3])
#      20     .loc[kind.title]
#      21     .dropna()
#      22     .reset_index(drop=True)
#      23 )
#      24 return df
#
# File ~\anaconda3\envs\rti\lib\site-packages\pandas\core\indexing.py:966, in _LocationIndexer.__getitem__(self, key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
# ...
